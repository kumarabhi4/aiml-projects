# %% [markdown]
# Part A:
# ----------
# Q 1. Please refer the table below to answer below questions:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import scipy.stats as stats
from scipy.stats import binom
import matplotlib.pyplot as plt

# %%
#1.A. Refer above table and find the joint probability of the people who planned to purchase and actually placed an order

#O = Actually ordered
#P = Planned to purchase
#n(P) = 500
#n(O) = 600

#p(O∩P) = 400

#𝑃(O∩P)= 400/600 = 0.66

P = 500
OP = 400  #planned to purchase and acutally ordered
TO = 2000  #Total number of observation

PO = round(OP/TO, 4)
print("a. So joint probability of the people who planned to purchase and actually placed an order is %1.4f" % PO) 

#1.B. Refer to the above table and find the joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase.


# P(A|B)=P(A and B)/P(B)

#
#P(A|B)=(Actually placed order, given people planned to purchase) = 400
#P(A)=(planned to purchase)= 500
#P(B)=(Actually purchased)= 600
#P(A and B) = P(A|B)*P(B)

#P1 = (Actually purchased)
P1 = 600/2000
#P2 = (Actually placed order, given people planned to purchase)
P2 = 400/2000
#P3 = P(A|B)*P(B)
P3 = P2*P1

print("b. joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase %1.4f" % P3)
# Out:
# a. So joint probability of the people who planned to purchase and actually placed an order is 0.2000
# b. joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase 0.0600

# %% [markdown]
# Q 2. An electrical manufacturing company conducts quality checks at specified periods on the products it manufactures. Historically, the failure rate for the manufactured item is 5%. Suppose a random sample of 10 manufactured items is selected. Answer the following questions.

# %%
p = 0.05
n = 10

#2.A. Probability that none of the items are defective? 
k = 0
P1 = stats.binom.pmf(k, n, p)
print('2.A. Probability that none of the items are defective is %1.4f' %P1)

#2.B. Probability that exactly one of the items is defective? 
k = 1
P2 = stats.binom.pmf(k, n, p)
print('2.B. Probability that exactly one of the items is defective is %1.4f' %P2)

#2.C. Probability that two or fewer of the items are defective? 
k = np.arange(0,3)
cb = stats.binom.cdf(k, n, p)
P3 = cb[2]
print('2.C. Probability that two or fewer of the items are defective is %1.4f' %P3)


#2.D. Probability that three or more of the items are defective ?
P4 = 1-P3
print('2.D. Probability that three or more of the items are defective is %1.4f' %P4)
# Out:
# 2.A. Probability that none of the items are defective is 0.5987
# 2.B. Probability that exactly one of the items is defective is 0.3151
# 2.C. Probability that two or fewer of the items are defective is 0.9885
# 2.D. Probability that three or more of the items are defective is 0.0115

# %% [markdown]
# Q 3. A car salesman sells on an average 3 cars per week.

# %%
rate = 3
n = np.arange(0,10)
poisson = stats.poisson.pmf(n,rate)
#3.A. What is Probability that in a given week he will sell some cars? 
P1 = 1-poisson[0]
print('3.A. Probability that in a given week he will sell some cars is %1.4f' %P1)
# Out:
# 3.A. Probability that in a given week he will sell some cars is 0.9502

# %%
#3.B. What is Probability that in a given week he will sell 2 or more but less than 5 cars? 
P2 = poisson[1] #probability to sell 2 cars
P3 = poisson[2] #probability to sell 3 cars
P4 = poisson[3] #probability to sell 4 cars

P = P2+P3+P4
print('3.B. Probability that in a given week he will sell 2 or more but less than 5 cars is %1.4f' %P)
# Out:
# 3.B. Probability that in a given week he will sell 2 or more but less than 5 cars is 0.5974

# %%
#3.C. Plot the poisson distribution function for cumulative probability of cars sold per-week vs number of cars sold per week.
rate = 3
x = np.arange(0, 11)

poisson_cdf = stats.poisson.cdf(x, rate)

plt.figure(figsize=(10, 6))
plt.plot(x, poisson_cdf)
plt.title('poisson distribution')
plt.xlabel('number of cars sold per week')
plt.ylabel('cumulative probability of cars sold per-week')
plt.grid(True)
plt.show()

# %% [markdown]
# Q 4. Accuracy in understanding orders for a speech based bot at a restaurant is important for the Company X which has designed,
# marketed and launched the product for a contactless delivery due to the COVID-19 pandemic. Recognition accuracy that measures the
# percentage of orders that are taken correctly is 86.8%. Suppose that you place an order with the bot and two friends of yours
# independently place orders with the same bot. Answer the following questions

# %%
p = 0.868
n = 3

#4.A. What is the probability that all three orders will be recognised correctly?
k = np.arange(0,4)
binom = stats.binom.pmf(k,n,p)

print('4.A. The probability that all three orders will be recognised correctly is %1.4f' %binom[3])

#4.B. What is the probability that none of the three orders will be recognised correctly?
print('4.B. The probability that none of the three orders will be recognised correctly is %1.4f' %binom[0])

#4.C. What is the probability that at least two of the three orders will be recognised correctly?
cdf_binom = stats.binom.cdf(k,n,p)
P = 1-cdf_binom[1]
print('4.C. The probability that at least two of the three orders will be recognised correctly is %1.4f' %P)
# Out:
# 4.A. The probability that all three orders will be recognised correctly is 0.6540
# 4.B. The probability that none of the three orders will be recognised correctly is 0.0023
# 4.C. The probability that at least two of the three orders will be recognised correctly is 0.9523

# %% [markdown]
# Q 5. Explain 1 real life industry scenario (other than the ones mentioned above) where you can use the concepts learnt in this module of Applied Statistics to get data driven business solution.
#
# Ans:- Efficacy rate of COVID detection kit is 75%. COVID infection average in the population of an area is 1%.
# What is the probability that if one is diagnosed with COVID, is actually infected with COVID.

# %% [markdown]
# PART B:
# ------------
# • DOMAIN: Sports
#
# • CONTEXT: Company X manages the men's top professional basketball division of the American league system. The dataset contains information on all the teams that have participated in all the past tournaments. It has data about how many baskets each team scored, conceded, how many times they came within the first 2 positions, how many tournaments they have qualified, their best position in the past, etc.
#
# • DATA DESCRIPTION: Basketball.csv - The data set contains information on all the teams so far participated in all the past tournaments.
#
# • DATA DICTIONARY:
#
# 1. Team: Team’s name
# 2. Tournament: Number of played tournaments.
# 3. Score: Team’s score so far.
# 4. PlayedGames: Games played by the team so far.
# 5. WonGames: Games won by the team so far.
# 6. DrawnGames: Games drawn by the team so far.
# 7. LostGames: Games lost by the team so far.
# 8. BasketScored: Basket scored by the team so far.
# 9. BasketGiven: Basket scored against the team so far.
# 10. TournamentChampion: How many times the team was a champion of the tournaments so far.
# 11. Runner-up: How many times the team was a runners-up of the tournaments so far.
# 12. TeamLaunch: Year the team was launched on professional basketball.
# 13. HighestPositionHeld: Highest position held by the team amongst all the tournaments played.
# • PROJECT OBJECTIVE: Company’s management wants to invest on proposals on managing some of the best teams in the league. The analytics
# department has been assigned with a task of creating a report on the performance shown by the teams. Some of the older teams are already in
# contract with competitors. Hence Company X wants to understand which teams they can approach which will be a deal win for them.

# %% [markdown]
# • STEPS AND TASK :
#
# 1. Read the data set, clean the data and prepare final dataset to be used for analysis.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# to restrict the float value to 3 decimal places
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
data = pd.read_csv('Basketball.csv',na_values=['-'])

# %%
data.head()
# Out:
#      Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0  Team 1          86  4385        2762     1647        552       563
# 1  Team 2          86  4262        2762     1581        573       608
# 2  Team 3          80  3442        2614     1241        598       775
# 3  Team 4          82  3386        2664     1187        616       861
# 4  Team 5          86  3368        2762     1209        633       920
#
#   BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 0         5947        3140                 33        23       1929
# 1         5900        3114                 25        25       1929
# 2         4534        3309                 10         8       1929
# 3         4398        3469                  6         6   1931to32
# 4         4631        3700                  8         7       1929
#
#    HighestPositionHeld
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# ...

# %%
data.tail()
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     -           -        -          -         -
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 56           38          66                  -         -    2009-10
# 57           37          57                  -         -    1956-57
# 58           51          85                  -         -    1951~52
# 59           34          65                  -         -    1955-56
# 60            -           -                  -         -    2017~18
#
#     HighestPositionHeld
# 56                   20
# 57                   16
# 58                   16
# ...

# %%
print("There are", data.shape[0], 'rows and', data.shape[1], "columns.")
# Out:
# There are 61 rows and 13 columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                60 non-null     float64
#  3   PlayedGames          60 non-null     float64
#  4   WonGames             60 non-null     float64
#  5   DrawnGames           60 non-null     float64
#  6   LostGames            60 non-null     float64
#  7   BasketScored         60 non-null     float64
#  8   BasketGiven          60 non-null     float64
#  9   TournamentChampion   9 non-null      float64
#  10  Runner-up            13 non-null     float64
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 6.3+ KB

# %%
data['HighestPositionHeld'].unique()
# Out:
# array([ 1,  3,  2,  4,  6,  8,  5, 11,  7, 12, 10, 17,  9, 19, 14, 16, 20,
#        15], dtype=int64)

# %%
data['Runner-up'].unique()
# Out:
# array([23., 25.,  8.,  6.,  7.,  4., nan,  3.,  1.,  5.])

# %%
data['TeamLaunch'].unique()
# Out:
# array(['1929', '1931to32', '1934-35', '1939-40', '1932-33', '1941to42',
#        '1948-49', '1944_45', '1935-36', '1949_50', '1933to34', '1960-61',
#        '1951-52', '1998-99', '1941-42', '1977-78', '1959-60', '2004to05',
#        '1961-62', '1940-41', '1930-31', '1963-64', '1974-75', '1943-44',
#        '1987-88', '1991_92', '2007-08', '1962-63', '1994-95', '1978-79',
#        '1971-72', '1999to00', '2014-15', '1990-91', '1947-48', '1996-97',
#        '1995-96', '1945-46', '1953-54', '1979-80', '1950-51', '2016_17',
#        '2009-10', '1956-57', '1951~52', '1955-56', '2017~18'],
#       dtype=object)

# %%
data['HighestPositionHeld'].unique()
# Out:
# array([ 1,  3,  2,  4,  6,  8,  5, 11,  7, 12, 10, 17,  9, 19, 14, 16, 20,
#        15], dtype=int64)

# %%
data['TeamLaunch'] = data['TeamLaunch'].replace(['to','_','~'],'-',regex=True)
data['TeamLaunch'] = data['TeamLaunch'].replace(['1929'],'1929-30')
#data['TeamLaunch'] = pd.to_datetime(data['TeamLaunch'],format='%Y-%y')
data['TeamLaunch'].unique()
# Out:
# array(['1929-30', '1931-32', '1934-35', '1939-40', '1932-33', '1941-42',
#        '1948-49', '1944-45', '1935-36', '1949-50', '1933-34', '1960-61',
#        '1951-52', '1998-99', '1977-78', '1959-60', '2004-05', '1961-62',
#        '1940-41', '1930-31', '1963-64', '1974-75', '1943-44', '1987-88',
#        '1991-92', '2007-08', '1962-63', '1994-95', '1978-79', '1971-72',
#        '1999-00', '2014-15', '1990-91', '1947-48', '1996-97', '1995-96',
#        '1945-46', '1953-54', '1979-80', '1950-51', '2016-17', '2009-10',
#        '1956-57', '1955-56', '2017-18'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                60 non-null     float64
#  3   PlayedGames          60 non-null     float64
#  4   WonGames             60 non-null     float64
#  5   DrawnGames           60 non-null     float64
#  6   LostGames            60 non-null     float64
#  7   BasketScored         60 non-null     float64
#  8   BasketGiven          60 non-null     float64
#  9   TournamentChampion   9 non-null      float64
#  10  Runner-up            13 non-null     float64
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 6.3+ KB

# %%
#Check for missing values in data
data.isnull().sum()
# Out:
# Team                    0
# Tournament              0
# Score                   1
# PlayedGames             1
# WonGames                1
# DrawnGames              1
# LostGames               1
# BasketScored            1
# BasketGiven             1
# TournamentChampion     52
# Runner-up              48
# TeamLaunch              0
# HighestPositionHeld     0
# dtype: int64

# %%
#Check for duplicate values in the data
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 2. Perform detailed statistical analysis and EDA using univariate, bi-variate and multivariate EDA techniques to get data driven insights on
# recommending which teams they can approach which will be a deal win for them. Also as a data and statistics expert you have to develop a
# detailed performance report using this data.
#
# Hint: Use statistical techniques and visualisation techniques to come up with useful metrics and reporting. Find out the best performing
# team, oldest team, team with highest goals, team with lowest performance etc. and many more. These are just random examples. Please
# use your best analytical approach to build this report. You can mix match columns to create new ones which can be used for better
# analysis. Create your own features if required. Be highly experimental and analytical here to find hidden patterns. Use graphical interactive
# libraries to enable you to publish interactive plots in python.

# %%
data.describe().T
# Out:
#                      count     mean      std    min     25%     50%      75%  \
# Tournament          61.000   24.000   26.827  1.000   4.000  12.000   38.000
# Score               60.000  916.450 1138.343 14.000 104.250 395.500 1360.500
# PlayedGames         60.000  810.100  877.465 30.000 115.500 424.500 1345.500
# WonGames            60.000  309.033  408.481  5.000  34.750 124.000  432.750
# DrawnGames          60.000  192.083  201.986  4.000  26.250  98.500  331.500
# LostGames           60.000  308.817  294.509 15.000  62.750 197.500  563.500
# BasketScored        60.000 1159.350 1512.064 34.000 154.500 444.000 1669.750
# BasketGiven         60.000 1159.233 1163.947 55.000 236.000 632.500 2001.250
# TournamentChampion   9.000    9.667   11.619  1.000   1.000   6.000   10.000
# Runner-up           13.000    6.615    8.109  1.000   1.000   4.000    7.000
# HighestPositionHeld 61.000    7.082    5.277  1.000   3.000   6.000   10.000
#
#                          max
# ...

# %% [markdown]
# Tournament: On an average 24 tournaments Teams played. 75% of Teams played equal to or more than 38 tournaments. There are some teams who played 86 tournaments.
#
# High performing team played more games, so std. deviation for Score, PlayedGames, WonGames, and BasketScored is high. In the same way low performing team conceded more baset so std. deviation for BasketGiven is high.

# %%
# Observation on Tournament played
sns.histplot(data=data, x='Tournament', stat='count')
plt.show()
sns.boxplot(data=data,x='Tournament')
plt.show()

# %% [markdown]
# Some high performing Teams played more tournaments.
# This is right skewed distribution.
# There are no outliers in this column.

# %%
sns.histplot(data=data, x='Score')
plt.show()
sns.boxplot(data=data,x='Score')
plt.show()

# %% [markdown]
# This is right skewed distribution.
#
# There are some outliers. More than 2900 score is being considered outlier here.

# %%
sns.histplot(data=data, x='PlayedGames', kde=True)
plt.show()
sns.boxplot(data=data,x='PlayedGames')
plt.show()

# %%
data.loc[data['PlayedGames']>1400].shape
# Out:
# (15, 13)

# %%
#Teams who palyed more than 1400 Games
data.loc[data['PlayedGames']>1400,'Team'].value_counts()
# Out:
# Team
# Team 1     1
# Team 2     1
# Team 3     1
# Team 4     1
# Team 5     1
# Team 6     1
# Team 7     1
# Team 8     1
# Team 9     1
# Team 10    1
# Team 11    1
# Team 12    1
# Team 13    1
# Team 14    1
# Team 15    1
# Name: count, dtype: int64

# %%
sns.histplot(data=data, x='WonGames', kde=True)
plt.show()
sns.boxplot(data=data,x='WonGames')
plt.show()

# %% [markdown]
# This is right skwed data as some teams are high performing teams. Here teams who won more than 1000 games are considered outliers.

# %%
#Teams who won more than 1000 Games
data.loc[data['WonGames']>1000,'Team'].value_counts()
# Out:
# Team
# Team 1    1
# Team 2    1
# Team 3    1
# Team 4    1
# Team 5    1
# Name: count, dtype: int64

# %%
#Teams who won more than 1500 Games, and are best performing teams
data.loc[data['WonGames']>1500,'Team']
# Out:
# 0    Team 1
# 1    Team 2
# Name: Team, dtype: object

# %%
#Observation on logGames by teams
sns.histplot(data=data, x='LostGames', kde=True)
plt.show()
sns.boxplot(data=data,x='LostGames')
plt.show()

#data.loc[data['LostGames']>10,'Team'].value_counts()

# %%
#Teams who lost more than 800 Games, and are worst performing teams
data.loc[data['LostGames']>800,'Team']
# Out:
# 3    Team 4
# 4    Team 5
# 5    Team 6
# 6    Team 7
# 7    Team 8
# Name: Team, dtype: object

# %%
#Observation on BaseketScored by teams
sns.histplot(data=data, x='BasketScored', kde=True)
plt.show()
sns.boxplot(data=data,x='BasketScored')
plt.show()

# %%
#Teams who scored more than 3500
data.loc[data['BasketScored']>3500,'Team']
# Out:
# 0    Team 1
# 1    Team 2
# 2    Team 3
# 3    Team 4
# 4    Team 5
# 5    Team 6
# 6    Team 7
# Name: Team, dtype: object

# %%
df=data[['Tournament','Score','PlayedGames','WonGames','DrawnGames','LostGames','BasketScored','BasketGiven','TournamentChampion','Runner-up','HighestPositionHeld']]
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap='Spectral',vmin=-1,vmax=1)
plt.show()

# %% [markdown]
# Observations:
# - Number of Tournament played, Score, PlayedGames, WonGames, DrawnGames, LostGames, BasketScored and BaseketGiven have very positive high correlation
# - TournamentChampion has high positive correlation with Score, WonGames, BasketScored, RunnerUp. TournamentChampion also has positive moderate correlation with Tournament, PlayedGames.
# - TournamentChampion has negetive correlation with LostGames

# %% [markdown]
# 3. Please include any improvements or suggestions to the association management on quality, quantity, variety, velocity, veracity etc. on the
# data points collected by the association to perform a better data analysis in future. At-least 1 suggestion for each point.

# %% [markdown]
# Below are my analysis on data in terms of quality, quantity, variety, velocity, veracity etc. :
# - Team :- More number of participating teams informaiton needed
# - Tournament :- If we can also catagorize the kind of tournament it was, like state level, school level etc.
# - Score :- Good quality of data collected
# - PlayedGames :- Good quality of data collected
# - WonGames :- Good quality of data collected
# - DrawnGames :- Good quality of data collected
# - LostGames :- Good quality of data collected
# - BasketScored :- I think we should have some data should be around the players who scored the max in a matc/tournament
# - BasketGiven :- Good quality of data collected
# - TournamentChampion :- Very less data collection, better quality on this point is expected
# - Runner-up :- Very less data collection, better quality on this point is expected
# - TeamLaunch :-  Better data quality as there were many discrepency in the data, and no uniformity. We should have this data which could be converted in the Datatime and not just the catagorical data.
# - HighestPositionHeld :- No clarity if when the team held higest position, did it win on loose.

# %% [markdown]
# PART C:
# ------

# %% [markdown]
# • **DOMAIN**: Startup ecosystem
#
# • **CONTEXT**: Company X is a EU online publisher focusing on the startups industry. The company specifically reports on the business related to technology news, analysis of emerging trends and profiling of new tech businesses and products. Their event i.e. Startup Battlefield is the world’s pre-eminent startup competition. Startup Battlefield features 15-30 top early stage startups pitching top judges in front of a vast live audience, present in person and online.
#
# • **DATA DESCRIPTION**: CompanyX_EU.csv - Each row in the dataset is a Start-up company and the columns describe the company.
#
# • **DATA DICTIONARY**:
# - 1. Startup: Name of the company
# - 2. Product: Actual product
# - 3. Funding: Funds raised by the company in USD
# - 4. Event: The event the company participated in
# - 5. Result: Described by Contestant, Finalist, Audience choice, Winner or Runner up
# - 6. OperatingState: Current status of the company, Operating ,Closed, Acquired or IPO
# - *Dataset has been downloaded from the internet. All the credit for the dataset goes to the original creator of the data.
# ---
#
# - **PROJECT OBJECTIVE**: Analyse the data of the various companies from the given dataset and perform the tasks that are specified in the below steps. Draw insights from the various attributes that are present in the dataset, plot distributions, state hypotheses and draw conclusions from the dataset.

# %% [markdown]
# • **STEPS AND TASK :**
# 1. Read the CSV file.
# 2. Data Exploration:
#     - A. Check the datatypes of each attribute.
#     - B. Check for null values in the attributes.

# %%
# Importing neccessary library:
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# to restrict the float value to 4 decimal places
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
#1.Readh the CSV file
data = pd.read_csv('CompanyX_EU.csv')

# %%
#2.A. Check the datatypes of each attribute.

data.info()
print("There are", data.shape[0], 'rows and', data.shape[1], "columns.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662 entries, 0 to 661
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Startup         662 non-null    object
#  1   Product         656 non-null    object
#  2   Funding         448 non-null    object
#  3   Event           662 non-null    object
#  4   Result          662 non-null    object
#  5   OperatingState  662 non-null    object
# dtypes: object(6)
# memory usage: 31.2+ KB
# There are 662 rows and 6 columns.

# %%
#2.B. Check for null values in the attributes.

data.isnull().sum()
# Out:
# Startup             0
# Product             6
# Funding           214
# Event               0
# Result              0
# OperatingState      0
# dtype: int64

# %%
# Check for any duplicate entries
df['Funding'].unique()
# Out:
# array(['$630K', '$1M', '$19.3M', '$29M', '$1.8M', '$750K', '$17.9K',
#        '$11.6M', '$929.2K', '$12.2M', '$1.9M', '$4M', '$3M', '$225K',
#        '$24M', '$746K', '$600K', '$7.1M', '$4.5M', '$50.9M', '$8.3M',
#        '$12.3M', '$190K', '$40M', '$520K', '$2.9M', '$320K', '$1.7M',
#        '$20K', '$205M', '$16.5M', '$2.8M', '$125K', '$350K', '$20.8M',
#        '$675K', '$6.5M', '$2M', '$118K', '$20.5M', '$7.2M', '$2.3M',
#        '$212K', '$7M', '$8.1M', '$8.5M', '$325K', '$150K', '$5M', '$60K',
#        '$8.8M', '$120K', '$3.1M', '$5.5M', '$2.2M', '$496K', '$1.4M',
#        '$32.5M', '$19M', '$475K', '$182.1M', '$6.7M', '$848K', '$1.3M',
#        '$12M', '$2.6M', '$411.5K', '$925K', '$35.4M', '$38M', '$37.1M',
#        '$6.8M', '$72M', '$64M', '$12.5M', '$900K', '$100K', '$7.3M',
#        '$983K', '$9.7M', '$5.4M', '$160K', '$300K', '$1.7B', '$10.1M',
#        '$485K', '$8M', '$4.3M', '$10M', '$34.6M', '$16.3M', '$2.4M',
# ...

# %% [markdown]
# 3. **Data preprocessing & visualisation:**
#     - A. Drop the null values.
#     - B. Convert the ‘Funding’ features to a numerical value.
#     - C. Plot box plot for funds in million.
#     - D. Check the number of outliers greater than the upper fence.
#     - E. Check frequency of the OperatingState features classes.

# %%
#3.A. Drop the null values.
df = data.dropna()
df.isnull().sum()
# Out:
# Startup           0
# Product           0
# Funding           0
# Event             0
# Result            0
# OperatingState    0
# dtype: int64

# %%
#3.B. Convert the ‘Funding’ features to a numerical value.
df.loc[:,'Funds_in_million'] = df['Funding'].apply(lambda x: float(x[1:-1])/1000 if x[-1] == 'K' else (float(x[1:-1])*1 if x[-1] == 'M' else float(x[1:-1])))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 446 entries, 1 to 661
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Startup           446 non-null    object
#  1   Product           446 non-null    object
#  2   Funding           446 non-null    object
#  3   Event             446 non-null    object
#  4   Result            446 non-null    object
#  5   OperatingState    446 non-null    object
#  6   Funds_in_million  446 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 27.9+ KB

# %%
df['Startup'].unique()
# Out:
# array(['3DLT', '3Dprintler', '5to1', '8 Securities', 'AdhereTech',
#        'AdRocket', 'Agrilyst', 'Aiden', 'AirBoxLab', 'Aircall',
#        'AirDroids', 'AirHelp', 'Akoha', 'Alicanto', 'Amen.', 'Angstro',
#        'Anyclip', 'App2you', 'Appbistro', 'AppChina', 'Ark', 'Artsy',
#        'asap54.com', 'Atlas Wearables', 'Ava', 'Avado', 'Babelverse',
#        'Badgeville', 'Beam', 'Beartooth', 'Beestar', 'BeFunky',
#        'Behold.ai', 'Betterment', 'BillGuard', 'BioBots', 'Birch',
#        'Birdpost', 'Bitcasa', 'Bitcovery', 'BitFusion.io', 'Blaze',
#        'BlazingDB', 'Bloomlife', 'Boomerang Commerce', 'Botify',
#        'BRANDiD - Shop. Like a Man.', 'Branto Inc.', 'Breezeworks',
#        'BroadClip', 'Burt', 'Buyosphere', 'Buyou', 'Cake Health',
#        'CallApp', 'Calliope Waterworks, Inc.', 'Carbon Health',
#        'Carbon Robotics', 'Caruma Technologies, Inc.', 'Case', 'CastTV',
#        'CatchFree', 'Ceedo Technologies', 'CENTURY Tech', 'Cinder',
# ...

# %%
#3.C. Plot box plot for funds in million.
sns.boxplot(data=df,x='Funds_in_million')
plt.show()

# %% [markdown]
# - The distribution is right skewed, even after conversion to millions.
# - There are many outliers present in this coulmn. Some have funding more than 200 million, and max it goes upto approx 600 Millions.
# - The upper limit for the funding is around 30 Million.

# %%
#3.D. Check the number of outliers greater than the upper fence.
upper_fence=df.loc[df['Funds_in_million']>30].count()
print("The number of outliers greater than the upper fence is %d" %upper_fence[5])
# Out:
# The number of outliers greater than the upper fence is 43

# %%
#3.E. Check frequency of the OperatingState features classes.
print("Frequency of the OperatingState features classes:")
df["OperatingState"].value_counts()
# Out:
# Frequency of the OperatingState features classes:
# OperatingState
# Operating    319
# Acquired      66
# Closed        57
# Ipo            4
# Name: count, dtype: int64

# %% [markdown]
# 4. **Statistical Analysis:**
# - A. Is there any significant difference between Funds raised by companies that are still operating vs companies that closed down?
# - B. Write the null hypothesis and alternative hypothesis.
# - C. Test for significance and conclusion
# - D. Make a copy of the original data frame.
# - E. Check frequency distribution of Result variables.
# - F. Calculate percentage of winners that are still operating and percentage of contestants that are still operating
# - G. Write your hypothesis comparing the proportion of companies that are operating between winners and contestants:
# - H. Test for significance and conclusion
# - I. Select only the Event that has ‘disrupt’ keyword from 2013 onwards.

# %%
#4.A. Is there any significant difference between Funds raised by companies that are still operating vs companies that closed down?

newdf=df.loc[(df['OperatingState']=='Operating') | (df['OperatingState']=='Closed')]

plt.figure(figsize=(10,5))
sns.boxplot(data=newdf,x='OperatingState',y='Funds_in_million',showfliers=False)
plt.show()

# %% [markdown]
# - Yes, there is significant difference between funds raised by companies that are still operating vs companies that closed down.
# - The median funds raised by the companies that closed down is approx 1M, vs 2.5M fund rased by the companies still operating.
# - The 3rd quartile for fund raised by the companies that closed down is approx 3.5M, vs 8M fund rased by the companies still operating.
# - The upper bound for fund raised by the companies that closed down is approx 7.5M, vs 18M fund rased by the companies still operating.

# %% [markdown]
# **4.B. Write the null hypothesis and alternative hypothesis.**
#
# **Null Hypothesis H0:** There is no difference between Funds raised by companies that are still operating vs company that are closed now.
#
# **Alternative Hypothesis H1:** There is difference between Funds raised by companies that are still operating vs company that are closed now.

# %% [markdown]
# **4.C. Test for significance and conclusion**

# %%
import numpy                     as     np
import pandas                    as     pd
from   scipy.stats               import ttest_1samp, ttest_ind
import matplotlib.pyplot         as     plt
import matplotlib
import seaborn as sns
import scipy.stats as stats
import statsmodels.stats.api as sm

#Alpha - 0.05

#STATISTICAL TEST

newdf1 = newdf[['OperatingState','Funds_in_million']]
newdf2 = newdf1.loc[newdf1['OperatingState']=='Closed']
newdf3 = newdf1.loc[newdf1['OperatingState']=='Operating']

#Calculate p value

t_statistic, p_value  = ttest_ind(newdf2['Funds_in_million'],newdf3['Funds_in_million'])

#print('tstat',t_statistic)    
#print('P Value',p_value)

# p_value < 0.05 => alternative hypothesis:
# they don't have the same mean at the 5% significance level
print ("two-sample t-test p-value=", p_value)

alpha_level = 0.05

if p_value < alpha_level:
    print('We have enough evidence to reject the null hypothesis in favour of alternative hypothesis')
    print('We conclude that there is significant difference between Funds raised by companies that are still operating vs company that are closed now.')
else:
    print('We do not have enough evidence to reject the null hypothesis in favour of alternative hypothesis')
    print('We conclude that there is no significant difference between Funds raised by companies that are still operating vs company that are closed now.')
# Out:
# two-sample t-test p-value= 0.08174275952723768
# We do not have enough evidence to reject the null hypothesis in favour of alternative hypothesis
# We conclude that there is no significant difference between Funds raised by companies that are still operating vs company that are closed now.

# %% [markdown]
# **4.D. Make a copy of the original data frame.**

# %%
# Original datafram is 'data' which we read the CSV file into
newdata = data.copy()

# %% [markdown]
# **4.E. Check frequency distribution of Result variables.**

# %%
sns.histplot(data=newdata, x='Result', kde=True)
plt.xticks(rotation=90)
plt.xlabel('Result')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **4.F.Calculate percentage of winners that are still operating and percentage of contestants that are still operating**

# %%
# percentage of winners that are still operating

newdatadf = newdata.loc[newdata['OperatingState']=='Operating']

percentage_result = newdatadf['Result'].value_counts(normalize=True)

print('Percentage of winners that are still operating is %1.4f' % percentage_result['Winner'])
print('Percentage of Contestants that are still operating is %1.4f' % percentage_result['Contestant'])
# Out:
# Percentage of winners that are still operating is 0.0409
# Percentage of Contestants that are still operating is 0.7140

# %% [markdown]
# **4.G. Write your hypothesis comparing the proportion of companies that are operating between winners and contestants:**

# %% [markdown]
# **Null Hypothesis H0:**  The proportion of companies that are still operating among winners is equal to the proportion of companies that are still operating among contestants.
# **Alternative Hypothesis H1:** The proportion of companies that are still operating among winners is not equal to the proportion of companies that are still operating among contestants.

# %% [markdown]
# **4.H. Test for significance and conclusion**

# %%
import numpy                     as     np
import pandas                    as     pd
from   scipy.stats        import    chi2_contingency
import matplotlib.pyplot         as     plt
import matplotlib
import math
import seaborn as sns
import scipy.stats as stats
import statsmodels.stats.api as sm



#STATISTICAL TEST

newdatadf = newdata.loc[newdata['OperatingState']=='Operating']

percentage_result = newdatadf['Result'].value_counts(normalize=True)

#The proportion
P1 = 0.0409
P2 = 0.7140

#Calculating sample size
sample_size = newdatadf['Result'].value_counts()

# Winnder sampel size
N1 = sample_size['Winner']
# Contestants sample size
N2 = sample_size['Contestant']

alpha_level = 0.05

# Calculating standared error
std_error = math.sqrt((P1*(1-P1))/N1 + (P2*(1-P2))/N2)

# z score
z = (P1-P2)/std_error

#Calculating p value

p_value = 2 * (1 - stats.norm.cdf(z))

if p_value < alpha_level:
    print('We have enough evidence to reject the null hypothesis in favour of alternative hypothesis')
else:
    print('We do not have enough evidence to reject the null hypothesis in favour of alternative hypothesis')
# Out:
# We do not have enough evidence to reject the null hypothesis in favour of alternative hypothesis

# %% [markdown]
# **4.I.Select only the Event that has ‘disrupt’ keyword from 2013 onwards.**

# %%
#prepare dataframe to compare with year

#Extract year information from the string data and create a new column
newdatadf['Event_Year']=newdatadf['Event'].str.extract('(\d+)')

#Convert Event_Year column into float for comparision
newdatadf['Event_Year']=newdatadf['Event_Year'].astype(float)

#Fetch only data which has event year >= 2013
df1 = newdatadf.loc[newdatadf['Event_Year']>=2013]

#Show only the Event that has ‘disrupt’ keyword from 2013 onwards.
df1.loc[df1['Event'].str.contains('Disrupt')]
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_11252\772074015.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdatadf['Event_Year']=newdatadf['Event'].str.extract('(\d+)')
# C:\Users\abhin\AppData\Local\Temp\ipykernel_11252\772074015.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdatadf['Event_Year']=newdatadf['Event_Year'].astype(float)
#              Startup             Product  Funding                Event  \
# ...
